# %% [markdown]
# # Animesh Rastogi, MSE Student, Civil Engineering
# ## Assignment 1

# %% [markdown]
# ### Ans1:-

# %%
import numpy as np
import matplotlib.pyplot as plt
A = 1
tau = 1
t = np.linspace(0,2,100)
W = A*(np.exp( -t/tau) - 1 + t/tau)
fig = plt.figure()
plt.plot(t,W, 'r')
plt.xlabel('t')
plt.ylabel('W(t)')
plt.show()

# %% [markdown]
# ### Ans2 and 3:-

# %%
A = [1,2,3]
tau = [1,2,3]
t = np.linspace(0,2,100)
W1 = A[0]*(np.exp( -t/tau[0]) - 1 + t/tau[0])
W2 = A[1]*(np.exp( -t/tau[1]) - 1 + t/tau[1])
W3 = A[2]*(np.exp( -t/tau[2]) - 1 + t/tau[2])
plt.plot(t,W1, 'r-')
plt.plot(t,W2, 'b--')
plt.plot(t,W3, 'g-.')
plt.xlabel('t')
plt.ylabel('W(t)')
plt.legend(['W1 (A = 1, tau = 1)','W2 (A = 2, tau = 2)','W3 (A = 3, tau = 3)'])
plt.show()

# %% [markdown]
# ### Ans4:-
#
# Figure out if the data is given as w and t or t and w - and complete the exercise accordingly

# %%
import pandas as pd
from scipy.optimize import curve_fit
def W(t,A,tau):
    return A*(np.exp( -t/tau) - 1 + t/tau)

data = pd.read_csv('wt.csv',header = None)
popt, pcov = sc.optimize.curve_fit(W,data[1],data[0])
plt.plot(data[1],data[0])
A = popt[0]
tau = popt[1]
t = np.linspace(0,30,100)
W = A*(np.exp( -t/tau) - 1 + t/tau)
plt.plot(t,W1, 'r')
plt.xlabel('t')
plt.ylabel('W(t)')
plt.show()

# %%
popt
# Out:
# array([0.03900459, 2.48283125])

# %%
popts
# Out:
# (array([0.03900459, 2.48283125]),
#  array([[3.47525109e-05, 1.92733835e-03],
#         [1.92733835e-03, 1.07447700e-01]]))
